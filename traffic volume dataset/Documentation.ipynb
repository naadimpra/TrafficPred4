# %% [markdown]
# # Traffic Volume Dataset Documentation
#
# This documentation provides an analysis of the Traffic Volume dataset. The dataset contains information about traffic volume at different time intervals and various weather conditions.
#
# ## Dataset Description
# The Traffic Volume dataset consists of the following columns:
#
# - **date_time**: The date and time of the recorded traffic volume.
# - **is_holiday**: Indicates whether the date corresponds to a holiday.
# - **air_pollution_index**: The air pollution index at the time of measurement.
# - **humidity**: The humidity level at the time of measurement.
# - **wind_speed**: The wind speed at the time of measurement.
# - **wind_direction**: The wind direction at the time of measurement.
# - **visibility_in_miles**: The visibility in miles at the time of measurement.
# - **dew_point**: The dew point at the time of measurement.
# - **temperature**: The temperature at the time of measurement.
# - **rain_p_h**: The amount of rainfall in mm/h at the time of measurement.
# - **snow_p_h**: The amount of snowfall in mm/h at the time of measurement.
# - **clouds_all**: The percentage of cloud cover at the time of measurement.
# - **weather_type**: The type of weather at the time of measurement.
# - **weather_description**: A description of the weather at the time of measurement.
# - **traffic_volume**: The number of vehicles recorded at the specified time.
#
# ## Importing Required Libraries and Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, Image

# Traffic volume dataset
traffic_volume_dataset = pd.read_csv('Train.csv')

# %% [markdown]
# # Dataset Analysis
# The dataset can be analyzed in several ways to gain insights into the traffic volume patterns. The following analyses are performed in this documentation:
#
# ## Distribution of Traffic Volume by Time Intervals
# The dataset is analyzed to identify patterns and trends in traffic volume based on different time intervals (hourly).

# %%
# Distribution of traffic volume based on different time intervals
traffic_volume_dataset['date_time'] = pd.to_datetime(traffic_volume_dataset['date_time'])
traffic_volume_dataset['hour'] = traffic_volume_dataset['date_time'].dt.hour

# Generate a text file for traffic volume by time intervals
traffic_volume_by_time_intervals = traffic_volume_dataset.groupby('hour')['traffic_volume'].mean()
traffic_volume_by_time_intervals.to_csv('traffic_volume_by_time_intervals.txt', sep='\t', index=False)

# Traffic volume visualization by time intervals
plt.figure(figsize=(10, 6))
sns.lineplot(x='hour', y='traffic_volume', data=traffic_volume_dataset)
plt.xlabel('Hour')
plt.ylabel('Traffic Volume')
plt.title('Traffic Volume by Time Intervals')
plt.savefig('traffic_volume_by_time_intervals.png')
plt.close()

display(Image(filename='traffic_volume_by_time_intervals.png'))

# %% [markdown]
# ## Impact of Holidays on Traffic Volume
# The dataset is analyzed to investigate whether traffic volume is affected by holidays.

# %%
# Investigate whether traffic volume is affected by holidays
plt.figure(figsize=(10, 6))
sns.barplot(x='is_holiday', y='traffic_volume', data=traffic_volume_dataset)
plt.xlabel('Holiday')
plt.ylabel('Traffic Volume')
plt.title('Traffic Volume by Holiday')
plt.savefig('traffic_volume_by_holiday.png')
plt.close()

display(Image(filename='traffic_volume_by_holiday.png'))

# %% [markdown]
# ## Relationship Between Air Pollution and Traffic Volume
# The dataset is analyzed to examine the relationship between air pollution levels and traffic volume.

# %%
# Analyze the relationship between air pollution levels and traffic volume
plt.figure(figsize=(10, 6))
sns.scatterplot(x='air_pollution_index', y='traffic_volume', data=traffic_volume_dataset)
plt.xlabel('Air Pollution Index')
plt.ylabel('Traffic Volume')
plt.title('Traffic Volume vs. Air Pollution Index')
plt.savefig('traffic_volume_vs_air_pollution_index.png')
plt.close()

display(Image(filename='traffic_volume_vs_air_pollution_index.png'))

# %% [markdown]
# # Impact of Weather Conditions on Traffic Volume
# The dataset is analyzed to explore how various weather conditions impact traffic volume.

# %%
# Explore how weather conditions impact traffic volume
weather_columns = ['humidity', 'wind_speed', 'wind_direction', 'visibility_in_miles', 'dew_point', 'temperature', 'rain_p_h', 'snow_p_h', 'clouds_all']
for column in weather_columns:
    plt.figure(figsize=(10, 6))
    sns.scatterplot(x=column, y='traffic_volume', data=traffic_volume_dataset)
    plt.xlabel(column.capitalize())
    plt.ylabel('Traffic Volume')
    plt.title(f'Traffic Volume vs. {column.capitalize()}')
    plt.savefig(f'traffic_volume_vs_{column}.png')
    plt.close()

    display(Image(filename=f'traffic_volume_vs_{column}.png'))

# %% [markdown]
# # Relationship Between Cloud Cover, Weather Types, Weather Descriptions, and Traffic Volume
# The dataset is analyzed to analyze the relationship between cloud cover, weather types, weather descriptions, and traffic volume.

# %%
# Analyze the relationship between cloud cover, weather types, weather descriptions, and traffic volume
weather_columns = ['clouds_all', 'weather_type', 'weather_description']
for column in weather_columns:
    plt.figure(figsize=(10, 6))
    sns.barplot(x=column, y='traffic_volume', data=traffic_volume_dataset)
    plt.xlabel(column.capitalize())
    plt.ylabel('Traffic Volume')
    plt.title(f'Traffic Volume by {column.capitalize()}')
    plt.xticks(rotation=45)
    plt.savefig(f'traffic_volume_by_{column}.png')
    plt.close()

    display(Image(filename=f'traffic_volume_by_{column}.png'))

# %% [markdown]
# ## Correlation Heatmap
# To understand the relationships between numerical variables in the dataset, we can create a correlation heatmap. The heatmap visually represents the correlation coefficients between pairs of variables. Higher positive values indicate a positive correlation, while higher negative values indicate a negative correlation.

# %%
# Correlation analysis
plt.figure(figsize=(12, 8))
correlation_matrix = traffic_volume_dataset.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.savefig('correlation_heatmap.png')
plt.close()

display(Image(filename='correlation_heatmap.png'))

# %% [markdown]
# # Conclusion
# The analysis of the Traffic Volume dataset reveals interesting insights into the traffic patterns. The distribution of traffic volume by time intervals highlights hourly variations, providing valuable information for traffic management and resource allocation. The investigation of holidays indicates whether traffic volume is influenced by special events, enabling better planning and traffic control. The examination of the relationship between air pollution levels and traffic volume helps understand potential correlations between environmental factors and traffic patterns.
#
# Furthermore, the impact of various weather conditions on traffic volume is explored, demonstrating how factors like humidity, wind speed, temperature, and visibility can affect traffic patterns. Additionally, the analysis of cloud cover, weather types, and weather descriptions provides insights into the relationship between weather and traffic volume.
#
# The findings from this analysis can be beneficial for traffic planning, infrastructure development, and transportation
